# %%
import xml.etree.ElementTree as ET

def extract_component_titles(xml_file_path):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Define namespaces
    ns = {'cda': 'urn:hl7-org:v3'}

    # Find all <component> elements
    components = root.findall(".//cda:component", namespaces=ns)

    # Extract titles from <title> elements within <component>
    titles = [component.find(".//cda:title", namespaces=ns).text.strip() if component.find(".//cda:title", namespaces=ns) is not None else None for component in components]

    return titles

def extract_information(xml_file_path, parameters):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Define namespaces
    ns = {'cda': 'urn:hl7-org:v3'}

    # Dictionary to store extracted information for each parameter
    extracted_data = {}

    for param in parameters:
        # Find all sections for the current parameter
        sections = root.findall(f".//cda:section[cda:title='{param['title']}']", namespaces=ns)

        # Extract information from the nested structure for each occurrence
        for idx, section in enumerate(sections, start=1):
            title = section.find(".//cda:title", namespaces=ns).text
            text_elements = section.findall(".//cda:text", namespaces=ns)

            # Create a list of rows
            rows = []

            for text_element in text_elements:
                table_element = text_element.find(".//cda:table", namespaces=ns)
                if table_element is not None:
                    # Extract table headers (or infer from the first row)
                    headers = [th.text.strip() if th.text is not None else '' for th in table_element.findall(".//cda:th", namespaces=ns)]
                    if not headers:
                        # Infer headers from the first row if no explicit headers are present
                        first_row = table_element.find(".//cda:tr", namespaces=ns)
                        headers = [td.text.strip() if td.text is not None else '' for td in first_row.findall(".//cda:td", namespaces=ns)]

                    # Extract table rows
                    for tr in table_element.findall(".//cda:tr", namespaces=ns):
                        row_data = [td.text.strip() if td.text is not None else '' for td in tr.findall(".//cda:td", namespaces=ns)]
                        rows.append(row_data)

            # Store extracted information in the dictionary
            param_name = f"{param['name']}_{idx}" if len(sections) > 1 else param['name']
            extracted_data[param_name] = {
                'Title': title,
                'Table Headers': headers,
                'Table Rows': rows
            }

    return extracted_data

# Example XML file path (replace this with the actual path to your XML file)
xml_file_path = 'Harry_Styles_0056_ClinicalSummary.xml'

# Extract component titles from the XML file
component_titles = extract_component_titles(xml_file_path)

# Filter out None values from the list
component_titles = [title for title in component_titles if title is not None]

# Create parameters_list using the extracted titles
parameters_list = [{'name': title, 'title': title} for title in component_titles]

# Extract information for all parameters
all_extracted_info = extract_information(xml_file_path, parameters_list)

# Print the extracted information for all parameters
for param_name, data in all_extracted_info.items():
    print(f"Parameter: {param_name}")
    print(f"Title: {data['Title']}")
    print(f"Table Headers: {data['Table Headers']}")
    print("Table Rows:")
    for row in data['Table Rows']:
        print(row)
    print()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=67'>68</a> xml_file_path = 'Harry_Styles_0056_ClinicalSummary.xml'
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=69'>70</a> # Extract component titles from the XML file
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=70'>71</a> component_titles = extract_component_titles(xml_file_path)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=72'>73</a> # Filter out None values from the list
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=73'>74</a> component_titles = [title for title in component_titles if title is not None]
#
# Untitled-1.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=2'>3</a> def extract_component_titles(xml_file_path):
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a>     # Parse the XML file
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=4'>5</a>     tree = ET.parse(xml_file_path)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=5'>6</a>     root = tree.getroot()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=7'>8</a>     # Define namespaces
#
# File c:\Users\anush\AppData\Local\Programs\Python\Python311\Lib\xml\etree\ElementTree.py:1218, in parse(source, parser)
#    1209 """Parse XML document into element tree.
#    1210
#    1211 *source* is a filename or file object containing XML data,
#    (...)
#    1215
#    1216 """
#    1217 tree = ElementTree()
# -> 1218 tree.parse(source, parser)
#    1219 return tree
#
# File c:\Users\anush\AppData\Local\Programs\Python\Python311\Lib\xml\etree\ElementTree.py:569, in ElementTree.parse(self, source, parser)
#     567 close_source = False
#     568 if not hasattr(source, "read"):
# --> 569     source = open(source, "rb")
#     570     close_source = True
#     571 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Harry_Styles_0056_ClinicalSummary.xml'

# %%
from tabulate import tabulate
import xml.etree.ElementTree as ET

def extract_component_titles(xml_file_path):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Define namespaces
    ns = {'cda': 'urn:hl7-org:v3'}

    # Find all <component> elements
    components = root.findall(".//cda:component", namespaces=ns)

    # Extract titles from <title> elements within <component>
    titles = [component.find(".//cda:title", namespaces=ns).text.strip() if component.find(".//cda:title", namespaces=ns) is not None else None for component in components]

    return titles

def extract_information(xml_file_path, parameters):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Define namespaces
    ns = {'cda': 'urn:hl7-org:v3'}

    # Dictionary to store extracted information for each parameter
    extracted_data = {}

    for param in parameters:
        # Find all sections for the current parameter
        sections = root.findall(f".//cda:section[cda:title='{param['title']}']", namespaces=ns)
        for idx, section in enumerate(sections, start=1):
            title = section.find(".//cda:title", namespaces=ns).text
            text_elements = section.findall(".//cda:text", namespaces=ns)
            rows = []
            for text_element in text_elements:
                table_element = text_element.find(".//cda:table", namespaces=ns)
                if table_element is not None:
                    # Extract table headers (or infer from the first row)
                    headers = [th.text.strip() if th.text is not None else '' for th in table_element.findall(".//cda:th", namespaces=ns)]
                    if not headers:
                        # Infer headers from the first row if no explicit headers are present
                        first_row = table_element.find(".//cda:tr", namespaces=ns)
                        headers = [td.text.strip() if td.text is not None else '' for td in first_row.findall(".//cda:td", namespaces=ns)]

                    # Extract table rows
                    for tr in table_element.findall(".//cda:tr", namespaces=ns):
                        row_data = [td.text.strip() if td.text is not None else '' for td in tr.findall(".//cda:td", namespaces=ns)]
                        rows.append(row_data)

            # Store extracted information in the dictionary
            param_name = f"{param['name']}_{idx}" if len(sections) > 1 else param['name']
            extracted_data[param_name] = {
                'Title': title,
                'Table Headers': headers,
                'Table Rows': rows
            }

    return extracted_data

# Example XML file path (replace this with the actual path to your XML file)
xml_file_path = 'Brock_Purdy_0059_ClinicalSummary.xml'

# Extract component titles from the XML file
component_titles = extract_component_titles(xml_file_path)

# Filter out None values from the list
component_titles = [title for title in component_titles if title is not None]

# Create parameters_list using the extracted titles
parameters_list = [{'name': title, 'title': title} for title in component_titles]

# Extract information for all parameters
all_extracted_info = extract_information(xml_file_path, parameters_list)

# Print the extracted information for all parameters
for param_name, data in all_extracted_info.items():
    print(param_name)
    print(tabulate(data['Table Rows'], headers=data['Table Headers'], tablefmt='html'))
# Out:
# Social History
# <table>
# <thead>
# <tr><th>Social History Element  </th><th>Description  </th></tr>
# </thead>
# <tbody>
# <tr><td>                        </td><td>             </td></tr>
# <tr><td>Patient Sex             </td><td>male         </td></tr>
# </tbody>
# </table>
# Allergies
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# PROBLEMS
# <table>
# <thead>
# <tr><th>Problem                                                            </th><th>Status  </th><th>Start Date  </th><th>Stop Date  </th></tr>
# </thead>
# <tbody>
# <tr><td>                                                                   </td><td>        </td><td>            </td><td>           </td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>06/16/2023  </td><td>           </td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>Chronic post-traumatic stress disorder , [SNOMED CT: 313182004]    </td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>Mild depression , [SNOMED CT: 310495003]                           </td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>Severe major depression, single episode , [SNOMED CT: 251000119105]</td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>Major depression in partial remission , [SNOMED CT: 30605009]      </td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Chronic post-traumatic stress disorder , [SNOMED CT: 313182004]    </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Chronic post-traumatic stress disorder , [SNOMED CT: 313182004]    </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Chronic post-traumatic stress disorder , [SNOMED CT: 313182004]    </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Mild depression , [SNOMED CT: 310495003]                           </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>Pain in the pharynx , [SNOMED CT: 162397003]                       </td><td>Active  </td><td>03/30/2023  </td><td>           </td></tr>
# <tr><td>Moderate major depression, single episode , [SNOMED CT: 15639000]  </td><td>Active  </td><td>03/30/2023  </td><td>           </td></tr>
# <tr><td>Severe major depression, single episode , [SNOMED CT: 251000119105]</td><td>Active  </td><td>03/30/2023  </td><td>           </td></tr>
# </tbody>
# </table>
# Medications/Supplements
# <table>
# <thead>
# <tr><th>Medication                                                           </th><th>Directions  </th><th>Status  </th><th>Start Date  </th><th>Stop Date  </th></tr>
# </thead>
# <tbody>
# <tr><td>                                                                     </td><td>            </td><td>        </td><td>            </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>06/26/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>06/16/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/23/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/23/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/22/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/18/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>05/09/2023  </td><td>           </td></tr>
# <tr><td>desvenlafaxine 25 mg oral tablet, extended release [ Desvenlafaxine ]</td><td>1 tablet(s) once a day before a meal  for 30 , oral route.
#
# Recommended times 8am, 2pm , 6pm.             </td><td>Active  </td><td>03/30/2023  </td><td>           </td></tr>
# </tbody>
# </table>
# Functional Status
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# MENTAL STATUS
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# Lab/Image Results
# <table>
# <thead>
# <tr><th>Name                </th><th>Result value  </th><th>Reference Range  </th><th>Interpretation  </th><th>Status   </th><th>Date      </th><th>Comments  </th></tr>
# </thead>
# <tbody>
# <tr><td>                    </td><td>              </td><td>                 </td><td>                </td><td>         </td><td>          </td><td>          </td></tr>
# <tr><td>Test:25-OH vitamin D</td><td>              </td><td>                 </td><td>                </td><td>         </td><td>          </td><td>          </td></tr>
# <tr><td>vitamin D           </td><td>12 ng/ml      </td><td>80.0 - 120.0     </td><td>Low             </td><td>Completed</td><td>06/16/2023</td><td>          </td></tr>
# </tbody>
# </table>
# Immunizations
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# Procedures
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# Encounter Diagnosis
# <table>
# <thead>
# <tr><th>Problem                                                            </th><th>Status  </th><th>Date      </th></tr>
# </thead>
# <tbody>
# <tr><td>                                                                   </td><td>        </td><td>          </td></tr>
# <tr><td>Mild depression , [SNOMED CT: 310495003]                           </td><td>Active  </td><td>05/22/2023</td></tr>
# <tr><td>Moderate major depression, single episode , [SNOMED CT: 15639000]  </td><td>Active  </td><td>03/30/2023</td></tr>
# <tr><td>Severe major depression, single episode , [SNOMED CT: 251000119105]</td><td>Active  </td><td>03/30/2023</td></tr>
# <tr><td>Major depression in partial remission , [SNOMED CT: 30605009]      </td><td>Active  </td><td>05/22/2023</td></tr>
# <tr><td>Post-traumatic stress disorder , [SNOMED CT: 47505003]             </td><td>Active  </td><td>05/18/2023</td></tr>
# <tr><td>Chronic post-traumatic stress disorder , [SNOMED CT: 313182004]    </td><td>Active  </td><td>05/18/2023</td></tr>
# <tr><td>Pain in the pharynx , [SNOMED CT: 162397003]                       </td><td>Active  </td><td>03/30/2023</td></tr>
# </tbody>
# </table>
# ASSESSMENTS
# <table>
# <thead>
# <tr><th>Date      </th><th>Assessment Notes  </th></tr>
# </thead>
# <tbody>
# <tr><td>          </td><td>                  </td></tr>
# <tr><td>05/18/2023</td><td>Case Formulation
# Diagnoses &amp; Differentials
# Plan                   </td></tr>
# </tbody>
# </table>
# TREATMENT PLAN
# <table>
# <thead>
# <tr><th>Date      </th><th>Notes                </th></tr>
# </thead>
# <tbody>
# <tr><td>          </td><td>                     </td></tr>
# <tr><td>05/18/2023</td><td>Blood Test           </td></tr>
# <tr><td>05/18/2023</td><td>CDC                  </td></tr>
# <tr><td>05/18/2023</td><td>Blood Test           </td></tr>
# <tr><td>05/18/2023</td><td>CDC                  </td></tr>
# <tr><td>06/16/2023</td><td>BASIC METABOLIC PANEL</td></tr>
# <tr><td>06/16/2023</td><td>CBC w/diff           </td></tr>
# <tr><td>06/16/2023</td><td>Hepatic (Liver) Panel</td></tr>
# <tr><td>06/16/2023</td><td>Blood cultures       </td></tr>
# <tr><td>06/16/2023</td><td>Sputum Culture       </td></tr>
# <tr><td>06/16/2023</td><td>Procalcitonin        </td></tr>
# <tr><td>06/16/2023</td><td>Rapid flu/RSV        </td></tr>
# <tr><td>06/16/2023</td><td>RVP                  </td></tr>
# </tbody>
# </table>
# Goals
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# Health Concerns
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# REASON FOR VISIT
# <table>
# <thead>
# <tr><th>Appointment Date  </th><th>Reason for Visit                </th></tr>
# </thead>
# <tbody>
# <tr><td>                  </td><td>                                </td></tr>
# <tr><td>05/05/2023        </td><td>${Encounter.Date}               </td></tr>
# <tr><td>05/18/2023        </td><td>patient suffering head pain     </td></tr>
# <tr><td>05/18/2023        </td><td>patient suffering from back pain</td></tr>
# <tr><td>05/22/2023        </td><td>patient has knee pain           </td></tr>
# <tr><td>05/23/2023        </td><td>patient has pain                </td></tr>
# <tr><td>05/23/2023        </td><td>suffers from back pain          </td></tr>
# </tbody>
# </table>
# Implants
# <table>
# <thead>
# <tr></tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# REASON FOR REFERRAL
# <table>
# <thead>
# <tr><th>Date      </th><th>Referred To  </th><th>Reason for Referral  </th></tr>
# </thead>
# <tbody>
# <tr><td>          </td><td>             </td><td>                     </td></tr>
# <tr><td>06/16/2023</td><td>Pritesh Patel</td><td>test                 </td></tr>
# <tr><td>06/19/2023</td><td>Pritesh Patel</td><td>test                 </td></tr>
# </tbody>
# </table>
# Notes section_1
# <table>
# <thead>
# <tr><th>Date      </th><th>Consultation Note  </th></tr>
# </thead>
# <tbody>
# <tr><td>          </td><td>                   </td></tr>
# <tr><td>06/16/2023</td><td>Patient: Brock Purdy
# Ref Provider:
# DX codes
# Post-traumatic stress disorder, unspecified [F43.10] .                    </td></tr>
# </tbody>
# </table>
# Notes section_2
# <table>
# <thead>
# <tr><th>Date      </th><th>Notes Type                </th><th>Summary Note  </th></tr>
# </thead>
# <tbody>
# <tr><td>          </td><td>                          </td><td>              </td></tr>
# <tr><td>05/18/2023</td><td>History of Present Illness</td><td>Psychiatric Review of Systems
# Over-Time Symptom Tracking
# Depression average over 2 weeks -- 10 Anxiety average over 2 weeks -- 10 Irritability average over 2 weeks -- 10 Psychiatric History
# Psychiatric Diagnoses
# Hospitalizations
# Suicide Attempts
# Self-harming, non-suicidal behavior
# Past Medication Trials
# Current Medications
# Violence/Property Destruction
# Outpatient MH Treatment Hx
# Neuropsychiatric/Genetic Testing
# Sexual Offending Hx
# Substance Use
# Tobacco/Nicotine    ⁃ Current    ⁃ Past    ⁃ Cigarettes       ⁃ 1/2 pack per day    ⁃ Chewing tobacco       ⁃ 2 can per day Caffeine    ⁃ Greater than 400 mg/day       ⁃ 2 or more energy drinks    ⁃ Caffeine after 3pm Alcohol    ⁃ Beer    ⁃ Wine    ⁃ Liquor    ⁃ Social/Occasional Drinking    ⁃ Dailly Drinking    ⁃ Weekly Drinking Illicit Substances    ⁃ Cocaine    ⁃ Heroin    ⁃ Methamphetamine    ⁃ Amphetamines    ⁃ Mushrooms    ⁃ PCP    ⁃ Ectasy    ⁃ Designer drugs Marijuana    ⁃ Multiple times per day               </td></tr>
# <tr><td>05/18/2023</td><td>Review of Systems         </td><td>PCP Name &amp;amp; Last Exam Date
# Medical Diagnoses
# Current Primary Care Medications
# Medication Allergies
# Relevant Surgeries
# Abnormal Labs
# Mental Status Exam
# Appearance and Behavior Cooperative Good eye contact Well groomed Appropriate interactions Ambivalent Cachexia
# Cognition Oriented x 3 Alert Coma Disoriented to person
# Affect Appropriate Congruent with mood
# Motor WNL Memory Recent - Intact Remote - Intact
# Judgment Intact Insight Intact Speech Normal Attention and Concentration Intact Thought Content NO suicidal ideation NO homicidal ideation
# Perceptual Disturbances NO perceptual disturbances Thought Process Linear               </td></tr>
# </tbody>
# </table>
